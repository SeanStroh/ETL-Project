# %%
import pandas as pd
import csv
from sqlalchemy import create_engine

# %%
accident_rate="../Excel_cleaned/acc_acc_rate_NTSB.csv"
destroyed_aircraft="../Excel_cleaned/num_rate_destroyed_aircraft.csv"
passenger_injury = "../Excel_cleaned/passenger_injury_rate.csv"

# %%
accident_rate = pd.read_csv(accident_rate)
destroyed_aircraft = pd.read_csv(destroyed_aircraft)
passenger_injury = pd.read_csv(passenger_injury)

# %%
accident_rate.dtypes
# Out:
# Year                                     int64
# Major Accidents                          int64
# Serious Accidents                        int64
# Injury                                   int64
# Damage                                   int64
# (millions)                             float64
# Major Accidents per Million hours      float64
# Serious Accidents per Million hours    float64
# Injury per Million hours               float64
# Damage per millions                    float64
# dtype: object

# %%
destroyed_aircraft.dtypes
# Out:
# Year                                              int64
# Hull Losses                                       int64
# Aircraft Hours Flown (millions)                 float64
# Hull Losses per Million Aircraft Hours Flown    float64
# dtype: object

# %%
passenger_injury.dtypes
# Out:
# Year                                                      int64
# Passenger Fatalities                                      int64
# Passenger Serious Injuries                                int64
# Total Passenger Enplanements (millions)                   int64
# Million Passenger Enplanements per Passenger Fatality    object
# dtype: object

# %%
passenger_injury = passenger_injury.drop(columns = ["Million Passenger Enplanements per Passenger Fatality"])

# %%
passenger_injury.dtypes
# Out:
# Year                                       int64
# Passenger Fatalities                       int64
# Passenger Serious Injuries                 int64
# Total Passenger Enplanements (millions)    int64
# dtype: object

# %%
passenger_injury
# Out:
#     Year  Passenger Fatalities  Passenger Serious Injuries  \
# 0   1983                     8                           8
# 1   1984                     1                           6
# 2   1985                   486                          20
# 3   1986                     4                          14
# 4   1987                   213                          39
# 5   1988                   255                          44
# 6   1989                   259                          55
# 7   1990                     8                          23
# 8   1991                    40                          19
# 9   1992                    25                          14
# 10  1993                     0                           7
# 11  1994                   228                          15
# 12  1995                   152                          15
# 13  1996                   319                          19
# 14  1997                     2                          21
# ...

# %%
merged = pd.merge(destroyed_aircraft, passenger_injury, on = "Year")
merged
# Out:
#     Year  Hull Losses  Aircraft Hours Flown (millions)  \
# 0   1983            2                            7.299
# 1   1984            2                            8.165
# 2   1985            8                            8.710
# 3   1986            2                            9.976
# 4   1987            5                           10.645
# 5   1988            3                           11.141
# 6   1989            7                           11.275
# 7   1990            3                           12.150
# 8   1991            5                           11.781
# 9   1992            3                           12.360
# 10  1993            1                           12.706
# 11  1994            3                           13.124
# 12  1995            3                           13.505
# 13  1996            5                           13.746
# 14  1997            2                           15.838
# 15  1998            0                           16.817
# ...

# %%
final_merged = pd.merge(merged, accident_rate, on = "Year")
final_merged.head()
# Out:
#    Year  Hull Losses  Aircraft Hours Flown (millions)  \
# 0  1983            2                            7.299
# 1  1984            2                            8.165
# 2  1985            8                            8.710
# 3  1986            2                            9.976
# 4  1987            5                           10.645
#
#    Hull Losses per Million Aircraft Hours Flown  Passenger Fatalities  \
# 0                                         0.274                     8
# 1                                         0.245                     1
# 2                                         0.918                   486
# 3                                         0.200                     4
# 4                                         0.470                   213
#
#    Passenger Serious Injuries  Total Passenger Enplanements (millions)  \
# 0                           8                                      325
# 1                           6                                      352
# ...

# %%
final_merged = final_merged.drop(columns = ["(millions)"])

# %%
final_merged.head()
# Out:
#    Year  Hull Losses  Aircraft Hours Flown (millions)  \
# 0  1983            2                            7.299
# 1  1984            2                            8.165
# 2  1985            8                            8.710
# 3  1986            2                            9.976
# 4  1987            5                           10.645
#
#    Hull Losses per Million Aircraft Hours Flown  Passenger Fatalities  \
# 0                                         0.274                     8
# 1                                         0.245                     1
# 2                                         0.918                   486
# 3                                         0.200                     4
# 4                                         0.470                   213
#
#    Passenger Serious Injuries  Total Passenger Enplanements (millions)  \
# 0                           8                                      325
# 1                           6                                      352
# ...

# %%
final_merged = final_merged[["Year", "Total Passenger Enplanements (millions)", "Aircraft Hours Flown (millions)", 
                             "Hull Losses", "Hull Losses per Million Aircraft Hours Flown", "Major Accidents", 
                             "Major Accidents per Million hours", "Serious Accidents", "Serious Accidents per Million hours", 
                             "Injury", "Injury per Million hours", "Damage", "Damage per millions", 
                            "Passenger Fatalities","Passenger Serious Injuries"]]

# %%
final_merged
# Out:
#     Year  Total Passenger Enplanements (millions)  \
# 0   1983                                      325
# 1   1984                                      352
# 2   1985                                      390
# 3   1986                                      427
# 4   1987                                      458
# 5   1988                                      466
# 6   1989                                      468
# 7   1990                                      483
# 8   1991                                      468
# 9   1992                                      494
# 10  1993                                      505
# 11  1994                                      545
# 12  1995                                      561
# 13  1996                                      592
# 14  1997                                      648
# 15  1998                                      650
# 16  1999                                      676
# 17  2000                                      701
# ...

# %%
final_merged = final_merged.rename(columns = {"Year":"Year",
                  "Passanger Enplanements (millions)":"Passanger_Enplanement",
                  "Aircraft Hours Flown (millions)":"Aircraftzz_Hours_Flown",
                  "Hull Losses": "Hull_Losses",
                  "Hull Losses per Million Aircraft Hours Flown":"Hull_Losses_per_Million_Aircraft_Hours_Flown",
                  "Major Accidents":"Major_Accidents",
                  "Major Accidents per Million hours": "Major_Accidents_per_Million_Aircraft_Hours_Flown",
                  "Serious Accidents":"Serious_Accidents",
                  "Serious Accidents per Million hours":"Serious_Accidents_per_Million_Aircraft_Hours_Flown",
                  "Injury":"Injuries",
                  "Injury per Million hours":"Injuries_per_Million_Aircraft_Hours_Flown",
                  "Damage":"Damages",
                  "Damage per millions":"Damage_per_Million_Aircraft_Hours_Flown",
                  "Passenger Fatalities":"Passenger_Fatalities",
                  "Passenger Serious Injuries":"Serious_Passenger_Injuries",})

# %%
final_merged
# Out:
#     Year  Passanger_Enplanement  Aircraftzz_Hours_Flown  Hull_Losses  \
# 0   1983                    325                   7.299            2
# 1   1984                    352                   8.165            2
# 2   1985                    390                   8.710            8
# 3   1986                    427                   9.976            2
# 4   1987                    458                  10.645            5
# 5   1988                    466                  11.141            3
# 6   1989                    468                  11.275            7
# 7   1990                    483                  12.150            3
# 8   1991                    468                  11.781            5
# 9   1992                    494                  12.360            3
# 10  1993                    505                  12.706            1
# 11  1994                    545                  13.124            3
# 12  1995                    561                  13.505            3
# ...

# %%
cd=final_merged.iloc[0]
cd
# Out:
# Year                                                  1983.000
# Passanger_Enplanement                                  325.000
# Aircraftzz_Hours_Flown                                   7.299
# Hull_Losses                                              2.000
# Hull_Losses_per_Million_Aircraft_Hours_Flown             0.274
# Major_Accidents                                          4.000
# Major Accidents per Million Aircraft Hours Flown         0.548
# Serious_Accidents                                        2.000
# Serious Accidents per Million Aircraft Hours Flown       0.274
# Injuries                                                 9.000
# Injuries per Million Aircraft Hours Flown                1.233
# Damages                                                  8.000
# Damage per Million Aircraft Hours Flown                  1.096
# Passenger_Fatalities                                     8.000
# Serious Passenger Injuries                               8.000
# ...

# %%
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
import pandas as pd
import psycopg2

# %%
Base.metadata.tables
# Out:
# immutabledict({})

# %%
class airplaines(Base):
  __tablename__ = 'plane_datass'
  id = Column(Integer, primary_key=True)
  Passanger_Enplanement = Column(Integer)
  Aircraftzz_Hours_Flown = Column(Integer)
  Hull_Losses =Column(Integer)
  Hull_Losses_per_Million_Aircraft_Hours_Flown =Column(Integer)
  Major_Accidents =Column(Integer)
  Major_Accidents_per_Million_Aircraft_Hours_Flown =Column(Integer)
  Serious_Accidents =Column(Integer)
  Serious_Accidents_per_Million_Aircraft_Hours_Flown =Column(Integer)
  Injuries =Column(Integer)
  Injuries_per_Million_Aircraft_Hours_Flown =Column(Integer)
  Damages =Column(Integer)
  Damage_per_Million_Aircraft_Hours_Flown = Column(Integer)
  Passenger_Fatalities = Column(Integer)
  Serious_Passenger_Injuries = Column(Integer)

# %%
Base.metadata.tables
# Out:
# immutabledict({'plane_datass': Table('plane_datass', MetaData(bind=None), Column('id', Integer(), table=<plane_datass>, primary_key=True, nullable=False), Column('Passanger_Enplanement', Integer(), table=<plane_datass>), Column('Aircraftzz_Hours_Flown', Integer(), table=<plane_datass>), Column('Hull_Losses', Integer(), table=<plane_datass>), Column('Hull_Losses_per_Million_Aircraft_Hours_Flown', Integer(), table=<plane_datass>), Column('Major_Accidents', Integer(), table=<plane_datass>), Column('Major_Accidents_per_Million_Aircraft_Hours_Flown', Integer(), table=<plane_datass>), Column('Serious_Accidents', Integer(), table=<plane_datass>), Column('Serious_Accidents_per_Million_Aircraft_Hours_Flown', Integer(), table=<plane_datass>), Column('Injuries', Integer(), table=<plane_datass>), Column('Injuries_per_Million_Aircraft_Hours_Flown', Integer(), table=<plane_datass>), Column('Damages', Integer(), table=<plane_datass>), Column('Damage_per_Million_Aircraft_Hours_Flown', Integer(), tab
# ...

# %%
#engine=psycopg2.connect(f"postgresql://postgres:postgres@localhost:5432/airplanes")
#engine.autocommit=True
#cursor=engine.cursor()
#sql='''Create database airplanes''';
#cursor.execute(sql)
engine = create_engine(f"postgresql://postgres:postgres@localhost:5432/airplanes")

# %%
engine.table_names()
# Out:
# []

# %%
final_merged.to_sql('plane_datass', con=engine, if_exists = "append")
